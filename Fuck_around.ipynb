# %%
from qiskit import QuantumCircuit, transpile
import matplotlib.pyplot as plt
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# %matplotlib inline
# !pip install qiskit-aer


# Create quantum circuit
qc = QuantumCircuit(2, 2)  # 2 qubits, 2 classical bits
qc.h(1)
qc.cx(1, 0)

# Measure qubits
qc.measure(0, 0)
qc.measure(1, 1)

# Draw the circuit
qc.draw('mpl')

# Use AerSimulator (modern replacement for qasm_simulator)
simulator = AerSimulator()

# Run the circuit 1000 times
result = simulator.run(qc, shots=1000).result()

# Get counts (measurement outcomes)
counts = result.get_counts()
print(counts)

# Plot histogram
plot_histogram(counts)
plt.show()
# Out:
# Requirement already satisfied: qiskit-aer in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (0.17.0)
# Requirement already satisfied: qiskit>=1.1.0 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from qiskit-aer) (2.0.0)
# Requirement already satisfied: numpy>=1.16.3 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from qiskit-aer) (2.2.5)
# Requirement already satisfied: scipy>=1.0 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from qiskit-aer) (1.15.3)
# Requirement already satisfied: psutil>=5 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from qiskit-aer) (7.0.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.16.0)
# Requirement already satisfied: sympy>=1.3 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from qiskit>=1.1.0->qiskit-aer) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from qiskit>=1.1.0->qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from qiskit>=1.1.0->qiskit-aer) (5.4.1)
# Requirement already satisfied: typing-extensions in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from qiskit>=1.1.0->qiskit-aer) (4.13.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.13.0)
# Requirement already satisfied: six>=1.5 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from python-dateutil>=2.8.0->qiskit>=1.1.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (6.1.1)
# Requirement already satisfied: setuptools in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/grahamburke/miniconda3/envs/cwq/lib/python3.13/site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit-aer) (1.3.0)
# {'00': 490, '11': 510}

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# Define your circuit with classical bits for measurement
qc = QuantumCircuit(2, 2)
qc.h(1)
qc.h(1)
qc.cx(1, 0)
qc.measure([0, 1], [0, 1])  # Measure both qubits

qc.draw('mpl')

# Use AerSimulator (modern replacement for qasm_simulator)
simulator = AerSimulator()

# Run the circuit 1000 times
result = simulator.run(qc, shots=1000).result()

# Get counts (measurement outcomes)
counts = result.get_counts()
print(counts)

# Plot histogram
plot_histogram(counts)
plt.show()
# Out:
# {'00': 1000}
